# %% [markdown]
# # **Tingkat Kehadiran Siswa dan Dampaknya terhadap Prestasi Akademik**

# %% [markdown]
# # **Import library**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np
from sklearn.impute import KNNImputer

# %% [markdown]
# # **Business Understanding**

# %% [markdown]
# ## **Bussiness Objective**

# %% [markdown]
#  Sekolah memiliki banyak data terkait aktivitas belajar siswa seperti jumlah login, durasi belajar, aktivitas forum, penggunaan internet, serta data nilai akademik dan kehadiran. Namun, pihak sekolah belum mengetahui secara pasti faktor apa yang paling berpengaruh terhadap performa akademik siswa. Oleh karena itu, diperlukan analisis untuk memahami hubungan antara perilaku belajar digital, kehadiran, dan hasil akademik agar sekolah dapat mengambil keputusan yang lebih tepat berbasis data. Tujuan dari analisis ini adalah untuk mengidentifikasi faktor-faktor yang memengaruhi performa akademik siswa serta membangun model prediksi kategori performa. Hasil analisis diharapkan dapat membantu sekolah mendeteksi siswa yang berisiko memiliki performa rendah dan memberikan intervensi yang sesuai untuk meningkatkan hasil belajar.

# %% [markdown]
# ## **Assess Situation**

# %% [markdown]
# Sekolah sudah memiliki data sebanyak 2000 siswa dengan 26 variabel yang berisi informasi tentang data diri siswa, aktivitas belajar online, kehadiran, dan nilai akademik. Data ini cukup lengkap dan relevan untuk dianalisis karena mencakup faktor perilaku belajar dan hasil akademik. Memang ada sedikit data yang kosong di beberapa kolom.

# %% [markdown]
# ## **Analytic Goals**

# %% [markdown]
# Tujuan dari analisis ini adalah untuk mengetahui faktor-faktor apa saja yang memengaruhi performa akademik siswa berdasarkan data yang tersedia, seperti aktivitas belajar online, kehadiran, serta nilai tugas dan ujian. Analisis ini juga bertujuan untuk memahami pola perbedaan antara siswa dengan performa tinggi, sedang, dan rendah. Selain itu, akan dibuat model prediksi yang dapat mengelompokkan siswa ke dalam kategori High, Medium, atau Low sehingga sekolah dapat lebih cepat mengetahui siswa yang membutuhkan perhatian atau bantuan tambahan.

# %% [markdown]
# ## **Project Plan**

# %% [markdown]
# Tahapan proyek dimulai dengan proses pembersihan data, seperti menangani data yang kosong dan memastikan semua data sudah sesuai format. Setelah itu dilakukan analisis eksplorasi untuk melihat pola, tren, dan hubungan antar variabel, misalnya hubungan antara kehadiran dengan nilai akhir atau aktivitas login dengan performa siswa. Selanjutnya dilakukan pemilihan variabel yang paling berpengaruh, kemudian membangun model klasifikasi untuk memprediksi kategori performa siswa. Terakhir, hasil model akan dievaluasi untuk melihat tingkat akurasinya, lalu disusun rekomendasi yang dapat digunakan oleh pihak sekolah dalam mengambil keputusan.

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ## **Memuat Dataset**

# %% [markdown]
# Dataset ini berasal dari data perilaku siswa pendidikan vokasi yang digunakan untuk menganalisis pola belajar dan mengevaluasi kinerja akademik siswa.

# %%
file = '/content/drive/MyDrive/AVD 2026/vocational_student_behavioral_dataset_V4.csv'

df = pd.read_csv(file)
df
# Out:
#      student_id  age  gender socioeconomic_status region  total_logins  \
# 0         S1861   19    Male                 High   West            59
# 1         S0354   24  Female               Medium  South            19
# 2         S1334   23    Male               Medium  North            44
# 3         S0906   23  Female               Medium   East            43
# 4         S1290   17    Male                 High  North            28
# ...         ...  ...     ...                  ...    ...           ...
# 1995      S1131   24  Female                 High  South            30
# 1996      S1295   20  Female                  Low  North            34
# 1997      S0861   18  Female                  Low  North            26
# 1998      S1460   23    Male                 High  South            46
# 1999      S1127   19  Female               Medium  North            42
#
#       weekly_login_count  avg_session_duration  resource_click_count  \
# ...

# %% [markdown]
# ## **Deksriptif Data**

# %% [markdown]
# ### **Informasi Dasar**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   student_id                   2000 non-null   object
#  1   age                          2000 non-null   int64
#  2   gender                       2000 non-null   object
#  3   socioeconomic_status         2000 non-null   object
#  4   region                       2000 non-null   object
#  5   total_logins                 2000 non-null   int64
#  6   weekly_login_count           2000 non-null   int64
#  7   avg_session_duration         1940 non-null   float64
#  8   resource_click_count         1940 non-null   float64
#  9   forum_posts                  2000 non-null   int64
#  10  quiz_attempts_count          2000 non-null   int64
#  11  video_watch_completion_rate  2000 non-null   float64
#  12  daily_internet_usage_mins    1940 non-null   float64
# ...

# %% [markdown]
# Berdasarkan data di atas, dapat diketahui bahwa dataset ini memiliki 2000 Baris dan 26 Kolom

# %% [markdown]
# ### **Informasi Lanjutan**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   student_id                   2000 non-null   object
#  1   age                          2000 non-null   int64
#  2   gender                       2000 non-null   object
#  3   socioeconomic_status         2000 non-null   object
#  4   region                       2000 non-null   object
#  5   total_logins                 2000 non-null   int64
#  6   weekly_login_count           2000 non-null   int64
#  7   avg_session_duration         1940 non-null   float64
#  8   resource_click_count         1940 non-null   float64
#  9   forum_posts                  2000 non-null   int64
#  10  quiz_attempts_count          2000 non-null   int64
#  11  video_watch_completion_rate  2000 non-null   float64
#  12  daily_internet_usage_mins    1940 non-null   float64
# ...

# %% [markdown]
# **1. student_id**
#
# * Jumlah baris: 2000
#
# * Tipe data: object
#
# * Deskripsi: ID siswa
#
# **2. age**
#
# * Jumlah baris: 2000
#
# * Tipe data: int64
#
# * Deskripsi: Usia siswa
#
# **3. gender**
#
# * Jumlah baris: 2000
#
# * Tipe data: object
#
# * Deskripsi: Jenis kelamin
#
# **4. socioeconomic_status**
#
# * Jumlah baris: 2000
#
# * Tipe data: object
#
# * Deskripsi: Status sosial ekonomi
#
# **5. region**
#
# * Jumlah baris: 2000
#
# * Tipe data: object
#
# * Deskripsi: Wilayah siswa
#
# **6. total_logins**
#
# * Jumlah baris: 2000
#
# * Tipe data: int64
#
# * Deskripsi: Total login ke sistem
#
# **7. weekly_login_count**
#
# * Jumlah baris: 2000
#
# * Tipe data: int64
#
# * Deskripsi: Jumlah login per minggu
#
# **8. avg_session_duration**
#
# * Jumlah baris: 1940
#
# * Tipe data: float64
#
# * Deskripsi: Rata-rata durasi sesi belajar
#
# **9. resource_click_count**
#
# * Jumlah baris: 1940
#
# * Tipe data: float64
#
# * Deskripsi: Jumlah klik materi belajar
#
# **10. forum_posts**
#
# * Jumlah baris: 2000
#
# * Tipe data: int64
#
# * Deskripsi: Jumlah posting forum
#
# **11. quiz_attempts_count**
#
# * Jumlah baris: 2000
#
# * Tipe data: int64
#
# * Deskripsi: Jumlah percobaan kuis
#
# **12. video_watch_completion_rate**
#
# * Jumlah baris: 2000
#
# * Tipe data: float64
#
# * Deskripsi: Tingkat penyelesaian video
#
# **13. daily_internet_usage_mins**
#
# * Jumlah baris: 1940
#
# * Tipe data: float64
#
# * Deskripsi: Durasi penggunaan internet harian
#
# **14. edu_sites_visit_count**
#
# * Jumlah baris: 2000
#
# * Tipe data: int64
#
# * Deskripsi: Kunjungan ke situs edukasi
#
# **15. nonedu_sites_visit_count**
#
# * Jumlah baris: 2000
#
# * Tipe data: int64
#
# * Deskripsi: Kunjungan ke situs non-edukasi
#
# **16. peak_usage_time**
#
# * Jumlah baris: 2000
#
# * Tipe data: object
#
# * Deskripsi: Waktu penggunaan tertinggi
#
# **17. tab_switch_count**
#
# * Jumlah baris: 2000
#
# * Tipe data: int64
#
# * Deskripsi: Jumlah perpindahan tab
#
# **18. total_classes**
#
# * Jumlah baris: 2000
#
# * Tipe data: int64
#
# * Deskripsi: Total kelas
#
# **19. classes_attended**
#
# * Jumlah baris: 2000
#
# * Tipe data: int64
#
# * Deskripsi: Kelas yang dihadiri
#
# **20. assignment_score_avg**
#
# * Jumlah baris: 2000
#
# * Tipe data: float64
#
# * Deskripsi: Rata-rata nilai tugas
#
# **21. quiz_score_avg**
#
# * Jumlah baris: 1940
#
# * Tipe data: float64
#
# * Deskripsi: Rata-rata nilai kuis
#
# **22. midterm_exam_score**
#
# * Jumlah baris: 2000
#
# * Tipe data: float64
#
# * Deskripsi: Nilai ujian tengah semester
#
# **23. final_exam_score**
#
# * Jumlah baris: 2000
#
# * Tipe data: float64
#
# * Deskripsi: Nilai ujian akhir
#
# **24. attendance_percentage**
#
# * Jumlah baris: 2000
#
# * Tipe data: float64
#
# * Deskripsi: Persentase kehadiran
#
# **25. overall_performance_score**
#
# * Jumlah baris: 2000
#
# * Tipe data: float64
#
# * Deskripsi: Skor kinerja keseluruhan
#
# **26. performance_label**
#
# * Jumlah baris: 2000
#
# * Tipe data: object
#
# * Deskripsi: Kategori performa siswa

# %% [markdown]
# ### **Informasi Statistik Deskriptif**

# %%
df.describe(include='all')
# Out:
#        student_id          age gender socioeconomic_status region  \
# count        2000  2000.000000   2000                 2000   2000
# unique       2000          NaN      2                    3      4
# top         S1124          NaN   Male               Medium   West
# freq            1          NaN   1027                  984    530
# mean          NaN    20.496500    NaN                  NaN    NaN
# std           NaN     2.313366    NaN                  NaN    NaN
# min           NaN    17.000000    NaN                  NaN    NaN
# 25%           NaN    18.000000    NaN                  NaN    NaN
# 50%           NaN    20.000000    NaN                  NaN    NaN
# 75%           NaN    23.000000    NaN                  NaN    NaN
# max           NaN    24.000000    NaN                  NaN    NaN
#
#         total_logins  weekly_login_count  avg_session_duration  \
# count    2000.000000         2000.000000           1940.000000
# ...

# %% [markdown]
# **1. Kelengkapan Data (Count)**
#
# Jumlah total transaksi pada dataset ini adalah 155 baris. Dari pemeriksaan kelengkapan data, diperoleh temuan sebagai berikut:
#
# * Kolom Profit memiliki 38 data kosong (155 - 117)
# * Kolom Product ID memiliki 124 data kosong (155 - 31)
#
# **Kesimpulan:**
# Hanya kolom Profit dan Product ID yang mengandung missing values, sedangkan kolom lainnya telah terisi lengkap sebanyak 155 data.
#
#
#
#
#
#
# ---
#
#
# **2. Perbandingan Mean dan Median (Pola Distribusi)**
#
# * Kolom Sales
#   * Mean = 2.269,12
#   * Median = 2.221,80
#
# Nilai rata-rata yang sedikit lebih tinggi dibanding median menunjukkan adanya beberapa transaksi dengan nilai penjualan sangat besar, meskipun secara umum distribusinya masih cukup seimbang.
#
# * Kolom Quantity
#   * Mean = 10,02
#   * Median = 6,00
#
# Selisih yang cukup jauh antara mean dan median mengindikasikan adanya transaksi pembelian dalam jumlah besar yang memengaruhi nilai rata-rata.
#
# * Kolom Profit
#
#   * Mean = 417,48
#   * Median = 276,84
#
# Perbedaan yang cukup besar antara mean dan median menunjukkan bahwa keuntungan dipengaruhi oleh sejumlah transaksi dengan profit tinggi, sementara sebagian besar transaksi berada pada tingkat keuntungan yang lebih rendah.
#
# **Kesimpulan:**
# Distribusi data cenderung condong ke kanan (right-skewed), di mana nilai-nilai ekstrem yang tinggi berperan besar dalam meningkatkan nilai rata-rata.
#
# ---
#
# **3. Nilai Minimum dan Maksimum (Pengecekan Kewajaran Data)**
#
# * Kolom Sales
#
#   * Minimum = 8,00
#
#   * Maksimum = 7.958,58
#
# * Kolom Quantity
#
#   * Minimum = 1
#
#   * Maksimum = 114
#
# * Kolom Profit
#
#   * Minimum = -2.211,16
#
#   * Maksimum = 3.979,08
#
# **Kesimpulan:**
#
# * Jumlah maksimum Quantity sebesar 114 unit dalam satu transaksi perlu ditinjau lebih lanjut untuk memastikan apakah merupakan pesanan skala besar atau potensi kesalahan input.
#
# * Nilai Profit negatif menunjukkan adanya transaksi yang mengalami kerugian signifikan.
#
# * Rentang nilai Sales yang cukup lebar mencerminkan variasi harga produk yang wajar pada bisnis retail berskala global.
#
# ---
#
# **4. Standar Deviasi (Tingkat Variasi Data)**
#
# * Kolom Sales
#
#   * Mean = 2.269,12
#
#   * Std = 1.557,60
#
#
# *  kolom Profit
#
#    * Mean = 417,48
#
#    * Std = 676,75
#
#
# **Kesimpulan:**
#
# Standar deviasi Sales yang relatif besar menunjukkan perbedaan nilai penjualan antar transaksi cukup tinggi.
#
# Pada kolom Profit, standar deviasi yang lebih besar daripada nilai rata-ratanya menandakan tingkat keuntungan yang sangat bervariasi, mulai dari kerugian hingga keuntungan yang sangat tinggi.

# %% [markdown]
# ## **Verifikasi Kualitas Data**

# %% [markdown]
# ### **Data Type Check**

# %% [markdown]
# Kita akan mengecek tipe data pada setiap kolom agar analisis dan visualisasi yang dibuat bisa akurat.
#
# Berdasarkan pengecekan, seluruh kolom pada dataset sudah memiliki tipe data yang sesuai dengan fungsinya. Kolom bertipe object digunakan untuk data kategori, sedangkan kolom numerik sudah menggunakan tipe data int dan float. Dengan demikian, data sudah siap digunakan untuk analisis lebih lanjut.

# %%
df.dtypes
# Out:
# student_id                      object
# age                              int64
# gender                          object
# socioeconomic_status            object
# region                          object
# total_logins                     int64
# weekly_login_count               int64
# avg_session_duration           float64
# resource_click_count           float64
# forum_posts                      int64
# quiz_attempts_count              int64
# video_watch_completion_rate    float64
# daily_internet_usage_mins      float64
# edu_sites_visit_count            int64
# nonedu_sites_visit_count         int64
# peak_usage_time                 object
# tab_switch_count                 int64
# total_classes                    int64
# classes_attended                 int64
# assignment_score_avg           float64
# quiz_score_avg                 float64
# midterm_exam_score             float64
# final_exam_score               float64
# attendance_percentage          float64
# ...

# %% [markdown]
# ### **Incosistent Values**

# %% [markdown]
# **1. peak usage tim**
#
# Berdasarkan hasil pengecekan nilai unik pada setiap kolom, tidak ditemukan inkonsistensi data yang signifikan. Nilai pada kolom kategorikal sudah konsisten dan tidak menunjukkan perbedaan penulisan yang dapat menyebabkan duplikasi data.
#
# Namun, kolom peak_usage_time tetap perlu diperhatikan karena berpotensi memiliki variasi format penulisan. Oleh karena itu, standarisasi nilai tetap disarankan sebelum dilakukan analisis lebih lanjut.

# %%
print(df['peak_usage_time'].unique())
# Out:
# ['Morning' 'Afternoon' 'Night' 'Evening']

# %% [markdown]
# **2. Category**
#
# Berdasarkan hasil pengecekan nilai unik pada kolom Category, tidak ditemukan perbedaan penulisan yang menunjukkan ketidakkonsistenan data. Seluruh nilai kategori sudah ditulis secara seragam dan merepresentasikan kategori produk dengan jelas. Oleh karena itu, kolom Category tidak memerlukan proses standarisasi lebih lanjut dan dapat langsung digunakan dalam analisis.

# %% [markdown]
# ### **Missing Values**

# %% [markdown]
# Pada tahap ini, kita akan melihat seberapa banyak data yang hilang pada setiap kolom. Berdasarkan hasil perhitungan null ratio, dapat dilihat bahwa sebagian besar kolom tidak memiliki missing values.
#
# Namun, terdapat beberapa kolom yang memiliki data hilang, yaitu:
#
# * avg_session_duration
# Memiliki missing values sebesar 3%, yang menunjukkan adanya sebagian kecil data durasi sesi belajar yang tidak tercatat. Persentase ini tergolong kecil, sehingga masih dapat ditangani dengan metode imputasi.
#
# * resource_click_count
# Memiliki missing values sebesar 3%, yang menandakan tidak seluruh aktivitas klik materi belajar tercatat secara lengkap.
#
# * daily_internet_usage_mins
# Memiliki missing values sebesar 3%, yang mengindikasikan adanya data penggunaan internet harian yang hilang.
#
# * quiz_score_avg
# Memiliki missing values sebesar 3%, yang menunjukkan tidak semua siswa memiliki data nilai kuis.
#
# Kolom lainnya memiliki nilai 0% missing values, sehingga tidak memerlukan penanganan khusus.
#
# **Kesimpulan:**
# Secara keseluruhan, jumlah data yang hilang pada dataset ini relatif kecil dan masih dapat ditangani tanpa perlu menghapus kolom, sehingga dataset tetap layak digunakan untuk analisis lebih lanjut.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                              Null Ratio in %
# student_id                               0.0
# age                                      0.0
# gender                                   0.0
# socioeconomic_status                     0.0
# region                                   0.0
# total_logins                             0.0
# weekly_login_count                       0.0
# avg_session_duration                     3.0
# resource_click_count                     3.0
# forum_posts                              0.0
# quiz_attempts_count                      0.0
# video_watch_completion_rate              0.0
# daily_internet_usage_mins                3.0
# edu_sites_visit_count                    0.0
# nonedu_sites_visit_count                 0.0
# peak_usage_time                          0.0
# tab_switch_count                         0.0
# total_classes                            0.0
# classes_attended                         0.0
# assignment_score_avg                     0.0
# ...

# %% [markdown]
# ### **Duplicated Values**

# %% [markdown]
# Hasil pengecekan menunjukkan tidak terdapat data duplikat pada dataset.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [student_id, age, gender, socioeconomic_status, region, total_logins, weekly_login_count, avg_session_duration, resource_click_count, forum_posts, quiz_attempts_count, video_watch_completion_rate, daily_internet_usage_mins, edu_sites_visit_count, nonedu_sites_visit_count, peak_usage_time, tab_switch_count, total_classes, classes_attended, assignment_score_avg, quiz_score_avg, midterm_exam_score, final_exam_score, attendance_percentage, overall_performance_score, performance_label]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# Terlihat pada dataset ini tidak terdapat data duplikat, sehingga tidak diperlukan penanganan khusus. Namun, apabila ingin melakukan penghapusan data duplikat, dapat digunakan perintah berikut:df = **df.drop_duplicates()**

# %% [markdown]
# ### **Outliers Values**

# %% [markdown]
# Pada tahap ini, dilakukan pengecekan outliers pada kolom numerik untuk memastikan data yang digunakan tetap akurat.
#
# Hasilnya menunjukkan bahwa beberapa kolom memiliki outliers, yaitu:
#
# * total_logins sebesar 1%
#
# * avg_session_duration sebesar 0,75%
#
# * forum_posts sebesar 0,80%
#
# * nonedu_sites_visit_count sebesar 0,75%
#
# * daily_internet_usage_mins sebesar 0,40%
#
# * edu_sites_visit_count sebesar 0,45%
#
# Kolom numerik lainnya memiliki persentase outliers 0%.
#
# Karena seluruh outliers yang ditemukan berada di bawah 1%, maka pengaruhnya terhadap analisis relatif kecil dan dapat diabaikan sesuai kebutuhan analisis.

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                        Persentase Outliers
# age                                         0.00
# total_logins                                1.00
# weekly_login_count                          0.00
# avg_session_duration                        0.75
# resource_click_count                        0.00
# forum_posts                                 0.80
# quiz_attempts_count                         0.00
# video_watch_completion_rate                 0.00
# daily_internet_usage_mins                   0.40
# edu_sites_visit_count                       0.45
# nonedu_sites_visit_count                    0.75
# tab_switch_count                            0.00
# total_classes                               0.00
# classes_attended                            0.00
# assignment_score_avg                        0.00
# quiz_score_avg                              0.00
# midterm_exam_score                          0.00
# final_exam_score                            0.00
# ...

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['total_logins'])
plt.title('Boxplot of Total Logins')
plt.ylabel('Total Logins')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['avg_session_duration'])
plt.title('Boxplot of Avg Session Duration')
plt.ylabel('Avg Session Duration')
plt.show()

# %% [markdown]
# # **Eksplorasi Data (EDA)**

# %% [markdown]
# ## **Comparison/Perbandingan**

# %% [markdown]
# **Aktivitas:**
# Membandingkan total aktivitas login mahasiswa di setiap wilayah (region).
#
# **Tujuan:**
# Mengetahui wilayah dengan tingkat aktivitas login tertinggi serta melihat perbedaan aktivitas antar wilayah.
#
# **Visualisasi:**
# Bar Chart (Grafik Batang).

# %%
login_region = df.groupby('region')['total_logins'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(
    x=login_region.index,
    y=login_region.values,
    palette='viridis',
    hue=login_region.index,
    legend=False
)
plt.title('Total Login Berdasarkan Region')
plt.xlabel('Region')
plt.ylabel('Total Logins')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Wilayah tempat siswa berada memiliki pengaruh terhadap tingkat aktivitas dan performa belajar.

# %% [markdown]
# ## **Composition/Komposisi**

# %% [markdown]
# **Aktivitas:**
# Melihat proporsi tingkat performa siswa berdasarkan performance_label.
#
# **Tujuan:**
# Mengetahui persentase siswa pada setiap kategori performa (rendah, sedang, tinggi).
#
# **Visualisasi:**
# Pie Chart (Grafik Lingkaran).

# %%
performance_dist = df['performance_label'].value_counts()

plt.figure(figsize=(8, 9))
performance_dist.plot(
    kind='pie',
    autopct='%1.1f%%',
    startangle=140
)
plt.title('Proporsi Performa Mahasiswa')
plt.ylabel('')
plt.axis('equal')
plt.show()

# %% [markdown]
# Mayoritas siswa memiliki performa yang cukup stabil, namun masih ada kelompok yang perlu perhatian khusus untuk peningkatan belajar.

# %% [markdown]
# ## **Distribution/Distribusi**

# %% [markdown]
# **Aktivitas:**
# Menganalisis penyebaran nilai overall_performance_score.
#
# **Tujuan:**
# Melihat apakah nilai performa siswa cenderung rendah, sedang, atau tinggi serta mengetahui pola distribusinya.
#
# **Visualisasi:**
# Histogram.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['overall_performance_score'], bins=20, kde=True)
plt.title('Distribusi Overall Performance Score')
plt.xlabel('Overall Performance Score')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Secara umum, performa akademik siswa berada pada tingkat sedang dan tidak terlalu timpang.

# %% [markdown]
# ## **Relationship/Hubungan**

# %% [markdown]
# **Aktivitas:**
# Menganalisis hubungan antara tingkat kehadiran (attendance_percentage) dengan skor performa keseluruhan.
#
# **Tujuan:**
# Mengetahui apakah kehadiran siswa berpengaruh terhadap performa akademik.
#
# **Visualisasi:**
# Heatmap (Matriks Korelasi).

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(
    df[['attendance_percentage', 'overall_performance_score']].corr(),
    annot=True,
    cmap='viridis',
    fmt='.2f'
)
plt.title('Korelasi Kehadiran dan Performa Mahasiswa')
plt.show()

# %% [markdown]
# Kehadiran berperan penting dalam performa siswa, tetapi bukan satu-satunya faktor penentu.

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## **Data Type**

# %% [markdown]
# ## **Inconsistent Values**

# %% [markdown]
# Langkah ini bertujuan untuk memastikan semua data teks (seperti nama wilayah atau kategori performa) memiliki format penulisan yang sama. Jika ada yang menulis dengan huruf kecil semua atau campuran, kita ubah semuanya menjadi huruf besar (Upper Case) agar komputer tidak bingung saat menghitung data.

# %%
# 1. Menyeragamkan kolom 'performance_label' (Status Performa)
df['performance_label'] = df['performance_label'].str.upper()

# 2. Menyeragamkan kolom 'region' (Wilayah)
df['region'] = df['region'].str.upper()

# 3. Menyeragamkan kolom 'socioeconomic_status' (Status Ekonomi)
df['socioeconomic_status'] = df['socioeconomic_status'].str.upper()

# Menampilkan hasil unik untuk memastikan data sudah rapi
print(df['performance_label'].unique())
print(df['region'].unique())
# Out:
# ['HIGH' 'LOW' 'MEDIUM']
# ['WEST' 'SOUTH' 'NORTH' 'EAST']

# %% [markdown]
# **Penjelasan:**
#
# Berdasarkan pengecekan yang dilakukan, berikut hasilnya:
#
# * **Standarisasi Teks:** Semua data pada kolom kategori (seperti Wilayah dan Label Performa) sudah diubah menjadi huruf kapital. Ini dilakukan supaya tidak ada data yang dianggap berbeda hanya karena perbedaan huruf besar/kecil.
#
# * **Kualitas Data:** Setelah dicek, tidak ditemukan kesalahan penulisan (typo) pada kategori utama. Semuanya sudah konsisten.
#
# * **Kerapian:** Tidak ditemukan spasi kosong yang tidak perlu di awal atau akhir kata yang bisa merusak analisis.
#
# **Kesimpulan:**
# Data sudah konsisten dan bersih. Langkah ini memastikan bahwa saat kita membuat grafik nanti, perhitungan jumlah siswa per wilayah atau per kategori performa akan akurat 100%.

# %% [markdown]
# ## **Missing Values**

# %% [markdown]
# Langkah ini dilakukan untuk mendeteksi apakah terdapat data yang kosong di dalam dataset. Pengecekan ini sangat penting untuk menjamin kualitas data, karena adanya nilai yang hilang dapat menyebabkan hasil analisis menjadi tidak akurat atau bias.

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# student_id                     0.0
# age                            0.0
# gender                         0.0
# socioeconomic_status           0.0
# region                         0.0
# total_logins                   0.0
# weekly_login_count             0.0
# avg_session_duration           3.0
# resource_click_count           3.0
# forum_posts                    0.0
# quiz_attempts_count            0.0
# video_watch_completion_rate    0.0
# daily_internet_usage_mins      3.0
# edu_sites_visit_count          0.0
# nonedu_sites_visit_count       0.0
# peak_usage_time                0.0
# tab_switch_count               0.0
# total_classes                  0.0
# classes_attended               0.0
# assignment_score_avg           0.0
# quiz_score_avg                 3.0
# midterm_exam_score             0.0
# final_exam_score               0.0
# attendance_percentage          0.0
# overall_performance_score      0.0
# performance_label              0.0
# dtype: float64

# %% [markdown]
# **Analisis Temuan:**
#
# Berdasarkan hasil pengecekan, terdapat nilai kosong sebesar **3.0%** pada beberapa kolom numerik seperti:
# * **avg_session_duration**,
# * **resource_click_count**,
# * **daily_internet_usage_mins**,
# * **quiz_score_avg**.

# %% [markdown]
# **Penanganan Data (Imputasi):**
#
# Untuk menjaga agar jumlah data tidak berkurang, kita akan melakukan imputasi menggunakan nilai Mean (Rata-rata) untuk kolom-kolom numerik yang bermasalah tersebut. Ini dilakukan agar distribusi data tetap terjaga.

# %%
df['avg_session_duration'] = df['avg_session_duration'].fillna(df['avg_session_duration'].dropna().mean())
df['resource_click_count'] = df['resource_click_count'].fillna(df['resource_click_count'].dropna().mean())
df['daily_internet_usage_mins'] = df['daily_internet_usage_mins'].fillna(df['daily_internet_usage_mins'].dropna().mean())
df['quiz_score_avg'] = df['quiz_score_avg'].fillna(df['quiz_score_avg'].dropna().mean())

# %% [markdown]
# **Verifikasi Akhir:**
#
# Setelah dilakukan imputasi, kita lakukan pengecekan ulang untuk memastikan seluruh kolom sudah ditangani

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio %'])
# Out:
#                              Null Ratio %
# student_id                            0.0
# age                                   0.0
# gender                                0.0
# socioeconomic_status                  0.0
# region                                0.0
# total_logins                          0.0
# weekly_login_count                    0.0
# avg_session_duration                  0.0
# resource_click_count                  0.0
# forum_posts                           0.0
# quiz_attempts_count                   0.0
# video_watch_completion_rate           0.0
# daily_internet_usage_mins             0.0
# edu_sites_visit_count                 0.0
# nonedu_sites_visit_count              0.0
# peak_usage_time                       0.0
# tab_switch_count                      0.0
# total_classes                         0.0
# classes_attended                      0.0
# assignment_score_avg                  0.0
# quiz_score_avg                        0.0
# ...

# %% [markdown]
# **Kesimpulan:**
#
# Seluruh missing values telah berhasil ditangani dengan metode imputasi rata-rata. Dataset kini sudah lengkap dan siap untuk digunakan dalam tahap analisis berikutnya tanpa adanya risiko bias akibat data yang kosong.

# %% [markdown]
# ## **Duplicated Values**

# %% [markdown]
# Tahap ini bertujuan untuk memastikan tidak ada data ganda yang tersimpan. Data duplikat bisa menyebabkan perhitungan statistik menjadi tidak akurat.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [student_id, age, gender, socioeconomic_status, region, total_logins, weekly_login_count, avg_session_duration, resource_click_count, forum_posts, quiz_attempts_count, video_watch_completion_rate, daily_internet_usage_mins, edu_sites_visit_count, nonedu_sites_visit_count, peak_usage_time, tab_switch_count, total_classes, classes_attended, assignment_score_avg, quiz_score_avg, midterm_exam_score, final_exam_score, attendance_percentage, overall_performance_score, performance_label]
# Index: []
#
# [0 rows x 26 columns]

# %%
df = df.drop_duplicates()

# %% [markdown]
# **Penjelasan:**
#
# Ditahap ini kita menggunakan perintah **df.duplicated()** untuk mengidentifikasi baris yang memiliki nilai identik di semua kolom. Jika ditemukan, baris ganda tersebut dihapus menggunakan **drop_duplicates().**
#
# **Kesimpulann:**
#
# Setelah dilakukan pengecekan, tidak ditemukan adanya data duplikat dalam dataset ini. Hal ini menandakan bahwa dataset sudah bersih dan setiap baris data benar-benar mewakili satu identitas siswa yang berbeda.

# %% [markdown]
# ## **Outliers Values**

# %% [markdown]
# Outlier adalah nilai yang terlalu jauh dari jangkauan data lainnya, misalnya ada nilai yang terlalu tinggi atau terlalu rendah dibandingkan mayoritas data siswa. Data seperti ini perlu dirapikan supaya tidak mengacaukan hasil rata-rata dan distribusi data nantinya.

# %%
results = []
cols = df.select_dtypes(include=['float64', 'int64']).drop(columns=['student_id'], errors='ignore')

for col in cols:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    percent_outliers = (len(outliers) / len(df)) * 100
    results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
display(results_df)
# Out:
#                              Persentase Outliers
# Kolom
# age                                         0.00
# total_logins                                1.00
# weekly_login_count                          0.00
# avg_session_duration                        0.00
# resource_click_count                        0.00
# forum_posts                                 0.80
# quiz_attempts_count                         0.00
# video_watch_completion_rate                 0.00
# daily_internet_usage_mins                   0.00
# edu_sites_visit_count                       0.45
# nonedu_sites_visit_count                    0.75
# tab_switch_count                            0.00
# total_classes                               0.00
# classes_attended                            0.00
# assignment_score_avg                        0.00
# quiz_score_avg                              0.00
# midterm_exam_score                          0.00
# final_exam_score                            0.00
# ...

# %% [markdown]
# Meskipun persentasenya tergolong kecil (di bawah 1%), keberadaan outlier pada kolom seperti jumlah postingan forum atau kunjungan situs pendidikan tetap perlu ditangani. Hal ini dilakukan agar nilai-nilai ekstrem tersebut tidak memengaruhi hasil perhitungan rata-rata secara keseluruhan.
#
# Oleh karena itu, tahap selanjutnya adalah melakukan Clipping untuk merapikan nilai-nilai tersebut agar masuk ke dalam rentang batas atas dan batas bawah yang wajar. Dengan begitu, data tetap bisa digunakan tanpa harus menghapus baris siswa tersebut dari dataset.

# %%
columns_to_impute = ["avg_session_duration", "daily_internet_usage_mins", "quiz_score_avg"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# **Kesimpulan:**
#
# data ini secara umum sudah sangat bagus karena hampir semua kolom penting memiliki persentase outlier 0%. Meski ada sedikit nilai ekstrem di bagian aktivitas digital (seperti jumlah login), jumlahnya sangat kecil karena di bawah 1%. Dengan menggunakan teknik clipping, nilai-nilai yang terlalu jauh tersebut berhasil dirapikan tanpa harus menghapus data siswanya. Hasilnya, dataset jadi lebih stabil dan siap dianalisis dengan lebih akurat tanpa terganggu angka-angka yang terlalu mencolok.

# %% [markdown]
# # **Construct Data**

# %% [markdown]
# # **Reduct Data**

# %% [markdown]
# Reduksi data bertujuan untuk menyederhanakan dataset dengan membuang variabel yang tidak memiliki kontribusi langsung dalam analisis. Dataset yang ringkas akan mempermudah fokus pada informasi yang paling penting.

# %%
df = df.drop('student_id', axis=1)

df = df[df['region'] != 'UNKNOWN']

display(df.head())
# Out:
#    age  gender socioeconomic_status region  total_logins  weekly_login_count  \
# 0   19    Male                 High   West            59                   6
# 1   24  Female               Medium  South            19                   9
# 2   23    Male               Medium  North            44                   2
# 3   23  Female               Medium   East            43                   4
# 4   17    Male                 High  North            28                   2
#
#    avg_session_duration  resource_click_count  forum_posts  \
# 0             66.079121                  22.0            2
# 1             52.658783                  50.0            2
# 2             45.854387                  10.0            2
# 3             48.918866                  76.0            0
# 4             59.170770                  31.0            3
#
#    quiz_attempts_count  ...  tab_switch_count  total_classes  \
# 0                    3  ...                12             60
# ...

# %% [markdown]
# **Penjelasan:**
#
# * **Penggunaan df.drop('student_id', axis=1):** Perintah ini berfungsi untuk membuang kolom student_id dari dataset. Kolom ini dihapus karena merupakan identitas unik yang tidak memiliki nilai statistik untuk diolah. Penghapusan dilakukan pada axis=1 yang merujuk pada sumbu kolom.
#
# * **Penggunaan df[df['region'] != 'UNKNOWN']:**
# Kode ini berfungsi untuk menyaring (filtering) baris data. Tujuannya adalah membuang data siswa yang memiliki kategori wilayah 'UNKNOWN'. Dengan cara ini, data yang tertinggal hanyalah data yang valid dan informatif.
#
# * **Penggunaan display(df.head()):**
# Perintah ini digunakan untuk menampilkan 5 baris teratas dataset guna memastikan secara visual bahwa kolom student_id sudah berhasil dihapus dan data sudah bersih.

# %% [markdown]
# **Kesimpulan:**
#
# Kolom seperti student_id hanyalah label identitas dan tidak memiliki nilai statistik untuk diolah. Dengan membuang kolom melalui perintah drop dan menyaring baris yang tidak valid dengan teknik filtering, dataset menjadi lebih ringan dan bersih dari gangguan (noise). Hal ini memastikan proses analisis nantinya akan jauh lebih efektif karena fokus sepenuhnya tertuju pada variabel-variabel yang benar-benar memengaruhi hasil belajar siswa. Selain itu, langkah ini juga dilakukan untuk menghindari kesalahan algoritma dalam membaca pola dan meningkatkan efisiensi komputasi agar proses pengolahan data menjadi lebih cepat dan akurat.

# %% [markdown]
# # **Bar Chart**

# %% [markdown]
# ## **Bar Chart Matplotlib**

# %%
TopAttendance = df['attendance_percentage'].value_counts().head(5).sort_values(ascending=False) # head() jumlah yang mau ditampilkan & Urutan

plt.figure(figsize=(10, 6)) # Ukuran
plt.bar(TopAttendance.index, TopAttendance.values, color='skyblue') # color warna
plt.xlabel('Persentase Kehadiran') # keterangan X label
plt.ylabel('Jumlah Siswa') # keterangan y label
plt.title('Top 5 Persentase Kehadiran Siswa') # Judul
plt.xticks(rotation=45, ha='right') # rotasi teks
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight**
#
# * Grafik menunjukkan persentase kehadiran siswa yang paling sering muncul dalam dataset. Hal ini membantu melihat pola umum kedisiplinan siswa dalam mengikuti kegiatan belajar di sekolah.
#
# * Jika sebagian besar data berada pada persentase kehadiran tinggi, maka dapat disimpulkan bahwa mayoritas siswa aktif mengikuti pembelajaran di kelas.
#
# * Variasi persentase kehadiran juga menunjukkan bahwa tidak semua siswa memiliki tingkat partisipasi yang sama, yang dapat mempengaruhi prestasi akademik mereka.
#
# **Action**
#
# * Sekolah dapat mengidentifikasi siswa dengan persentase kehadiran rendah untuk mengetahui penyebabnya dan memberikan dukungan seperti bimbingan atau konseling.
#
# * Pihak sekolah dapat meningkatkan sistem monitoring kehadiran, misalnya dengan sistem absensi digital atau pengingat kepada siswa dan orang tua.
#
# * Data ini dapat digunakan untuk analisis lanjutan antara kehadiran dan nilai akademik, sehingga dapat diketahui apakah kehadiran benar-benar mempengaruhi prestasi belajar siswa.

# %% [markdown]
# ## **Bar Chart Seaborn**

# %%
TopAttendance = df['attendance_percentage'].value_counts().head(8).sort_values(ascending=False) # head() jumlah yang mau ditampilkan & Urutan
df_filtered = df[df['attendance_percentage'].isin(TopAttendance.index)]

plt.figure(figsize=(10, 6)) # Ukuran
sns.countplot(x='attendance_percentage', data=df_filtered, hue="gender", palette='rocket', order=TopAttendance.index) # palette (warna)
plt.title('Jumlah Siswa Berdasarkan Persentase Kehadiran dan Gender') # Judul
plt.xlabel('Persentase Kehadiran') # Keterangan X
plt.ylabel('Jumlah Siswa') # Keterangan Y
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Insight**
#
# * Grafik menunjukkan jumlah siswa pada beberapa persentase * kehadiran yang paling sering muncul dalam dataset. Hal ini membantu melihat pola umum kehadiran siswa dalam mengikuti kegiatan belajar.
#
# * Perbandingan warna pada grafik memperlihatkan distribusi siswa berdasarkan gender pada setiap tingkat kehadiran, sehingga dapat diketahui apakah terdapat perbedaan pola kehadiran antar kelompok siswa.
#
# * Jika sebagian besar siswa berada pada persentase kehadiran tinggi, maka hal ini menunjukkan tingkat partisipasi yang baik dalam proses pembelajaran yang dapat mendukung peningkatan prestasi akademik.
#
# **Action**
#
# * Sekolah dapat memantau siswa dengan persentase kehadiran rendah agar dapat mengetahui penyebabnya dan memberikan dukungan yang diperlukan.
#
# * Guru dapat mendorong peningkatan kehadiran siswa dengan membuat kegiatan pembelajaran yang lebih menarik dan interaktif.
#
# * Data ini juga dapat digunakan untuk analisis lanjutan antara kehadiran siswa dan nilai akademik, sehingga sekolah dapat memahami seberapa besar pengaruh kehadiran terhadap prestasi belajar.

# %% [markdown]
# # **Pie Chart**

# %% [markdown]
# ## **Pie Chart Matplotlib kolom 1**

# %%
plt.figure(figsize=(10, 6)) # ukuran
TopAttendance = df['attendance_percentage'].value_counts().head(8)
plt.pie(TopAttendance, labels=TopAttendance.index, autopct='%1.1f%%', colors=['lightcoral', 'lightgreen', 'gold','skyblue','orange']) # colors (warna)
plt.title('Distribusi Persentase Kehadiran Siswa') # Judul
plt.show()

# %% [markdown]
# **Insight**
#
# * Distribusi Tingkat Kehadiran Siswa
# Diagram pie menunjukkan bagaimana persentase kehadiran siswa tersebar dalam dataset. Dari grafik ini dapat dilihat kategori kehadiran mana yang memiliki jumlah siswa paling besar dibandingkan dengan yang lain.
#
# * Dominasi Kehadiran Tinggi atau Rendah
# Jika sebagian besar bagian pie didominasi oleh persentase kehadiran yang tinggi, maka hal ini menunjukkan bahwa mayoritas siswa memiliki tingkat partisipasi yang baik dalam mengikuti kegiatan belajar di kelas.
#
# * Indikasi Potensi Dampak pada Prestasi Akademik
# Kehadiran yang tinggi biasanya memberikan kesempatan lebih besar bagi siswa untuk memahami materi pelajaran secara langsung, sehingga berpotensi meningkatkan prestasi akademik mereka.
#
# **Action**
#
# * Mempertahankan Tingkat Kehadiran Tinggi
# Sekolah dapat mempertahankan tingkat kehadiran yang sudah baik dengan memberikan motivasi atau penghargaan kepada siswa yang memiliki kehadiran tinggi.
#
# * Intervensi untuk Siswa dengan Kehadiran Rendah
# Jika terdapat kelompok siswa dengan persentase kehadiran rendah, pihak sekolah dapat melakukan pendekatan seperti konseling atau pendampingan belajar.
#
# * Analisis Lanjutan Hubungan Kehadiran dan Nilai
# Data ini dapat dikombinasikan dengan nilai ujian atau performa akademik untuk mengetahui seberapa besar pengaruh kehadiran terhadap keberhasilan belajar siswa.

# %% [markdown]
# ## **Pie Chart Matplotlib kolom lain**

# %%
attendance_by_gender = df.groupby('gender')['attendance_percentage'].sum().sort_values(ascending=False)
attendance_by_gender_top3 = attendance_by_gender.head(3)

plt.figure(figsize=(10, 8)) # Ukuran
attendance_by_gender_top3.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Proporsi 3 Kelompok Siswa Berdasarkan Total Persentase Kehadiran') # Judul
plt.ylabel('') # Keterangan Y
plt.axis('equal')
plt.show()

# %% [markdown]
# **Insight**
#
# * Distribusi Kehadiran Berdasarkan Gender
# Grafik pie menunjukkan proporsi total persentase kehadiran siswa pada masing-masing kelompok gender. Hal ini membantu melihat kelompok mana yang memiliki kontribusi kehadiran lebih besar dalam dataset.
#
# * Perbandingan Partisipasi Siswa
# Jika salah satu kelompok memiliki proporsi yang lebih besar, hal ini menunjukkan bahwa kelompok tersebut memiliki tingkat partisipasi yang lebih tinggi dalam mengikuti kegiatan belajar.
#
# * Indikasi Hubungan dengan Prestasi Akademik
# Tingkat kehadiran yang lebih tinggi dapat memberikan peluang lebih besar bagi siswa untuk mengikuti pembelajaran secara konsisten sehingga berpotensi meningkatkan pemahaman materi dan prestasi akademik.
#
# **Action**
#
# * Evaluasi Partisipasi Siswa
# Sekolah dapat mengevaluasi apakah terdapat perbedaan tingkat kehadiran antar kelompok siswa dan mencari faktor yang mempengaruhinya.
#
# * Program Motivasi Kehadiran
# Jika terdapat kelompok dengan kehadiran lebih rendah, pihak sekolah dapat membuat program motivasi atau kegiatan yang meningkatkan keterlibatan siswa dalam proses belajar.
#
# * Analisis Lanjutan dengan Nilai Akademik
# Data ini dapat dikombinasikan dengan nilai ujian atau performa akademik untuk mengetahui apakah kelompok dengan kehadiran lebih tinggi juga memiliki prestasi akademik yang lebih baik.

# %% [markdown]
# # **Line Chart**

# %% [markdown]
# ## **Line Chart Matplotlib**

# %%
# Group berdasarkan persentase kehadiran
GrupPerAttendance = df.groupby('attendance_percentage').size()

plt.figure(figsize=(20, 6)) # Ukuran figure diperbesar untuk kejelasan
plt.plot(GrupPerAttendance.index, GrupPerAttendance.values, marker='o', color='blue')
plt.title('Tren Jumlah Siswa Berdasarkan Persentase Kehadiran', fontsize=16) # Judul
plt.xlabel('Persentase Kehadiran', fontsize=12) # X Keterangan
plt.ylabel('Jumlah Siswa', fontsize=12) # Y Keterangan
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight**
#
# * Distribusi Kehadiran Siswa
# Grafik line chart menunjukkan jumlah siswa pada setiap tingkat persentase kehadiran. Dari grafik ini dapat terlihat tingkat kehadiran yang paling sering muncul dalam dataset siswa.
#
# * Identifikasi Pola Kehadiran
# Jika grafik menunjukkan bahwa sebagian besar siswa berada pada persentase kehadiran yang tinggi, hal ini menandakan bahwa tingkat partisipasi siswa dalam mengikuti pembelajaran cukup baik.
#
# * Indikasi Pengaruh terhadap Prestasi Akademik
# Kehadiran yang tinggi biasanya berkaitan dengan peluang yang lebih besar bagi siswa untuk memahami materi pelajaran secara langsung, sehingga berpotensi meningkatkan prestasi akademik mereka.
#
# **Action**
#
# * Pemantauan Kehadiran Secara Berkala
# Sekolah dapat memantau pola kehadiran siswa secara berkala untuk mengetahui apakah terdapat kelompok siswa dengan tingkat kehadiran yang rendah.
#
# * Program Peningkatan Disiplin Kehadiran
# Guru dan pihak sekolah dapat membuat program motivasi atau penghargaan bagi siswa dengan tingkat kehadiran tinggi agar siswa lebih termotivasi untuk hadir di kelas.
#
# * Pendampingan untuk Siswa dengan Kehadiran Rendah
# Jika terdapat siswa dengan kehadiran yang rendah, pihak sekolah dapat memberikan pendampingan atau konseling agar mereka tetap dapat mengikuti proses belajar dengan baik.

# %% [markdown]
# # **Histogram**

# %% [markdown]
# ## **Histogram Matplotlib**

# %%
# Histogram (Matplotlib): Distribusi Persentase Kehadiran Siswa
plt.figure(figsize=(8, 5))
plt.hist(df['attendance_percentage'], bins=20, color='green', edgecolor='black')
plt.title('Distribusi Persentase Kehadiran Siswa')
plt.xlabel('Persentase Kehadiran')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# **Insight**
#
# * Sebaran tingkat kehadiran siswa
# Histogram menunjukkan bagaimana distribusi persentase kehadiran siswa dalam dataset. Kita dapat melihat apakah mayoritas siswa memiliki kehadiran tinggi, sedang, atau rendah.
#
# * Identifikasi kelompok siswa tertentu
# Jika grafik menunjukkan banyak siswa berada pada rentang kehadiran tinggi (misalnya di atas 80%), hal ini menandakan bahwa sebagian besar siswa cukup aktif mengikuti kegiatan pembelajaran.
#
# * Indikasi potensi pengaruh terhadap prestasi akademik
# Kehadiran yang tinggi biasanya memberikan kesempatan lebih besar bagi siswa untuk memahami materi secara langsung di kelas, sehingga berpotensi berdampak positif terhadap hasil belajar.
#
# **Action**
#
# * Meningkatkan monitoring kehadiran siswa
# Sekolah dapat menggunakan data kehadiran untuk memantau pola kehadiran siswa dan mendeteksi lebih awal jika terdapat siswa dengan tingkat kehadiran rendah.
#
# * Memberikan motivasi atau penghargaan bagi siswa dengan kehadiran tinggi
# Program penghargaan atau apresiasi dapat meningkatkan motivasi siswa untuk tetap disiplin dalam mengikuti kegiatan belajar.
#
# * Pendampingan bagi siswa dengan kehadiran rendah
# Guru atau pihak sekolah dapat memberikan bimbingan atau konseling kepada siswa yang memiliki tingkat kehadiran rendah agar mereka tetap dapat mengikuti proses pembelajaran dengan baik.

# %% [markdown]
# ## **Histogram Seaborn**

# %%
# Histogram (Seaborn)
plt.figure(figsize=(8, 5))
sns.histplot(df['attendance_percentage'], bins=20, kde=True, color='skyBlue')
plt.title('Distribusi Persentase Kehadiran Siswa')
plt.xlabel('Persentase Kehadiran')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# **Insight**
#
# * **Distribusi tingkat kehadiran siswa :**
# Histogram menunjukkan bagaimana sebaran persentase kehadiran siswa dalam dataset. Grafik ini membantu melihat apakah mayoritas siswa memiliki tingkat kehadiran tinggi atau rendah.
#
# * **Pola dominasi kehadiran :**
# Jika sebagian besar data terkumpul pada persentase kehadiran yang tinggi, hal ini menunjukkan bahwa mayoritas siswa aktif mengikuti kegiatan pembelajaran di kelas.
#
# * **Indikasi potensi pengaruh terhadap prestasi akademik**
# Kehadiran yang tinggi memberikan peluang lebih besar bagi siswa untuk mengikuti materi pembelajaran secara langsung sehingga dapat meningkatkan pemahaman dan berpotensi meningkatkan prestasi akademik.
#
# **Action**
#
# * **Monitoring kehadiran siswa secara rutin :**
# Sekolah dapat memantau distribusi kehadiran siswa untuk mengetahui apakah terdapat kelompok siswa dengan kehadiran rendah yang memerlukan perhatian khusus.
#
# * **Program peningkatan kedisiplinan kehadiran :**
# Guru dapat memberikan motivasi atau penghargaan kepada siswa yang memiliki tingkat kehadiran tinggi agar dapat mendorong siswa lain untuk lebih disiplin.
#
# * **Pendampingan bagi siswa dengan kehadiran rendah :**
# Jika ditemukan kelompok siswa dengan tingkat kehadiran rendah, sekolah dapat memberikan bimbingan atau konseling untuk membantu mereka tetap mengikuti proses pembelajaran dengan baik.

# %% [markdown]
# # **Boxplot**

# %% [markdown]
# ## **Boxplot Matplotlib**

# %%
# Boxplot (Matplotlib): Persentase Kehadiran berdasarkan Gender

# Identifikasi gender terbanyak
top_gender = df['gender'].value_counts().index

# Filter DataFrame untuk hanya menyertakan gender tersebut
df_top_gender = df[df['gender'].isin(top_gender)]

plt.figure(figsize=(12, 7)) # Ukuran figure
df_top_gender.boxplot(column='attendance_percentage', by='gender', ax=plt.gca(), grid=False, patch_artist=True, medianprops=dict(color='Black'))
plt.title('Distribusi Persentase Kehadiran Berdasarkan Gender', fontsize=16) # Judul
plt.xlabel('Gender', fontsize=12) # X Keterangan
plt.ylabel('Persentase Kehadiran', fontsize=12) # Y Keterangan
plt.xticks(rotation=0)
plt.suptitle('') # Menghilangkan judul default dari boxplot.by
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight**
#
# * **Perbandingan tingkat kehadiran antar gender**
# Boxplot memperlihatkan distribusi persentase kehadiran antara kelompok siswa berdasarkan gender. Grafik ini membantu melihat apakah terdapat perbedaan pola kehadiran antar kelompok siswa.
#
# * **Analisis median dan variasi kehadiran**
# Garis median pada boxplot menunjukkan nilai tengah dari persentase kehadiran siswa. Jika median antar gender berbeda, hal ini dapat menunjukkan adanya perbedaan kebiasaan kehadiran di kelas.
#
# * **Deteksi outlier kehadiran siswa**
# Titik yang berada di luar whisker menunjukkan siswa dengan kehadiran yang sangat rendah atau sangat tinggi dibandingkan mayoritas siswa lainnya.
#
# **Action**
#
# * **Evaluasi faktor yang mempengaruhi kehadiran siswa**
# Jika terdapat perbedaan distribusi kehadiran antar gender, sekolah dapat meneliti faktor yang mempengaruhi tingkat kehadiran tersebut.
#
# * **Pendampingan bagi siswa dengan kehadiran rendah**
# Siswa yang termasuk dalam kategori outlier dengan kehadiran rendah dapat diberikan perhatian khusus seperti bimbingan akademik atau konseling.
#
# * **Analisis lanjutan terhadap prestasi akademik**
# Data kehadiran ini dapat dikombinasikan dengan nilai ujian siswa untuk melihat apakah kehadiran yang lebih tinggi berkorelasi dengan prestasi akademik yang lebih baik.

# %% [markdown]
# ## **Boxplot Seaborn**

# %%
# Boxplot (Seaborn): Persentase Kehadiran berdasarkan Gender

# Identifikasi kategori gender
top_gender = df['gender'].value_counts().index

# Filter DataFrame (opsional, mengikuti struktur kode kamu)
df_top_gender = df[df['gender'].isin(top_gender)]

plt.figure(figsize=(12, 7)) # Ukuran figure
sns.boxplot(x='gender', y='attendance_percentage', data=df_top_gender, palette='rocket', order=top_gender, hue='gender', legend=False)
plt.title('Distribusi Persentase Kehadiran Berdasarkan Gender', fontsize=16) # Judul
plt.xlabel('Gender', fontsize=12) # X Keterangan
plt.ylabel('Persentase Kehadiran', fontsize=12) # Y Keterangan
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight**
#
# * **Perbandingan distribusi kehadiran antar gender**
# Boxplot menunjukkan bagaimana sebaran persentase kehadiran siswa pada masing-masing gender. Dari grafik ini dapat terlihat apakah terdapat perbedaan pola kehadiran antara kelompok siswa.
#
# * **Identifikasi median dan variasi kehadiran**
# Garis tengah pada boxplot menunjukkan nilai median kehadiran siswa, sementara kotak dan garis whisker menunjukkan variasi data. Hal ini membantu mengetahui apakah kehadiran siswa relatif stabil atau memiliki perbedaan yang besar.
#
# * **Deteksi outlier dalam kehadiran siswa**
# Titik yang berada di luar whisker menunjukkan outlier atau siswa dengan tingkat kehadiran yang sangat rendah atau sangat tinggi dibandingkan mayoritas siswa.
#
# **Action**
#
# * **Evaluasi pola kehadiran antar kelompok siswa**
# Jika terdapat perbedaan distribusi kehadiran yang signifikan antar gender, sekolah dapat mengevaluasi faktor yang mempengaruhi perbedaan tersebut.
#
# * **Intervensi bagi siswa dengan kehadiran rendah**
# Outlier dengan kehadiran sangat rendah dapat menjadi fokus perhatian guru atau wali kelas untuk diberikan bimbingan tambahan.
#
# * **Menghubungkan dengan prestasi akademik**
# Data kehadiran ini dapat dianalisis lebih lanjut dengan nilai akademik siswa untuk melihat apakah siswa dengan kehadiran tinggi memiliki performa akademik yang lebih baik.

# %% [markdown]
# # **Scatter**

# %% [markdown]
# ## **Scatter matplotlib**

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['attendance_percentage'], df['overall_performance_score'], alpha=0.7, color='teal')
plt.title('Hubungan Antara Kehadiran dan Performa Siswa')
plt.xlabel('Persentase Kehadiran')
plt.ylabel('Overall Performance Score')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight**
#
# * Terdapat hubungan yang cukup jelas antara persentase kehadiran siswa dengan overall performance score. Siswa dengan tingkat kehadiran yang lebih tinggi cenderung memiliki performa akademik yang lebih baik dibandingkan siswa dengan tingkat kehadiran yang rendah.
#
# * Pola pada scatter plot menunjukkan adanya kecenderungan peningkatan nilai performa seiring dengan meningkatnya tingkat kehadiran siswa. Meskipun terdapat beberapa variasi data, secara umum siswa dengan kehadiran lebih konsisten memiliki nilai performa yang lebih tinggi.
#
# * Hal ini menunjukkan bahwa kehadiran dalam proses pembelajaran berperan penting dalam membantu siswa memahami materi yang diajarkan sehingga berdampak pada peningkatan prestasi akademik.
#
# **Action**
#
# * Sekolah dapat meningkatkan monitoring kehadiran siswa untuk memastikan siswa mengikuti proses pembelajaran secara konsisten.
#
# * Guru dapat memberikan pendampingan tambahan kepada siswa dengan tingkat kehadiran rendah, karena kelompok ini berpotensi memiliki performa akademik yang lebih rendah.
#
# * Institusi pendidikan juga dapat membuat program motivasi peningkatan kehadiran, seperti pemberian penghargaan bagi siswa dengan tingkat kehadiran tinggi untuk mendorong peningkatan prestasi akademik.

# %% [markdown]
# # **Bubble Chart**

# %%
plt.figure(figsize=(12, 8))

sns.scatterplot(
    x='attendance_percentage',
    y='overall_performance_score',
    size='avg_session_duration',
    hue='gender',
    data=df,
    sizes=(50, 1000),
    alpha=0.7,
    palette='viridis'
)

plt.title('Hubungan Kehadiran dan Performa Akademik (Ukuran: Durasi Sesi Belajar, Warna: Gender)', fontsize=16)
plt.xlabel('Persentase Kehadiran', fontsize=12)
plt.ylabel('Skor Performa Akademik', fontsize=12)

plt.grid(True)
plt.legend(title='Gender', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Analisis**
#
# * **Kehadiran (Sumbu X):** Semakin ke kanan, kehadiran makin tinggi. Titik yang di atas biasanya ada di sebelah kanan. Artinya, rajin hadir = nilai bagus.
#
# * **Durasi Belajar (Ukuran Bubble):** Semakin besar bulatan, semakin lama siswa belajar per sesi. Bubble besar dominan di area atas, artinya durasi belajar yang lama bantu dongkrak nilai.
#
# * **Gender (Warna):** Membedakan pola antara laki-laki dan perempuan untuk melihat siapa yang lebih aktif atau berprestasi.
#
# **Action**
# * **Prioritas Kehadiran:** Fokus dorong kehadiran siswa karena ini penentu utama performa akademik.
#
# * **Kualitas Belajar:** Ajak siswa tidak hanya sering login, tapi juga memperlama durasi belajar mereka (perbesar bubble).
#
# * **Pantau "Zona Merah":** Awasi siswa dengan bulatan kecil di pojok kiri bawah. Mereka yang paling jarang hadir dan belajarnya singkat adalah yang paling berisiko gagal.

# %%
# Memilih kolom numerik yang relevan dari dataset vocational
cols = ['total_logins', 'avg_session_duration', 'resource_click_count',
        'quiz_attempts_count', 'attendance_percentage', 'overall_performance_score']

plt.figure(figsize=(10, 8))
sns.heatmap(data=df[cols].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f',
            linewidths=0.5)

plt.title('Korelasi Aktivitas Belajar vs Performa Siswa')
plt.show()

# %% [markdown]
# **Analisis**
# * **Waktu Belajar vs Performa**: Semakin terang warna (mendekati angka 1) pada pertemuan kolom daily_internet_usage_mins dan overall_performance_score, berarti makin lama siswa belajar, makin tinggi nilainya.
#
# * **Kehadiran vs Performa:** Kotak korelasi attendance_percentage menunjukkan seberapa kuat pengaruh hadir di kelas terhadap hasil ujian. Jika angkanya tinggi, berarti kehadiran adalah kunci utama.
#
# * **Pola Gender:** Heatmap ini merangkum seluruh data siswa. Jika ada perbedaan warna yang mencolok antar gender, itu artinya strategi pendekatan untuk laki-laki dan perempuan mungkin perlu dibedakan.
#
# **Action**
# * **Dorong Kehadiran:** Fokus ke siswa dengan tingkat kehadiran rendah karena mereka paling berisiko punya nilai jelek.
#
# * **Tambah Jam Belajar:** Arahkan siswa untuk lebih aktif di platform (internet usage) karena durasi belajar terbukti meningkatkan skor.
#
# * **Monitoring Ketat:** Pantau siswa yang kehadirannya rendah sekaligus jarang belajar—mereka adalah target utama intervensi sekolah.

# %% [markdown]
# # **Menyimpan DataSet Bersih**

# %%
df.to_csv("[CLEAN]Student_Performance_Data.csv", index=False)
